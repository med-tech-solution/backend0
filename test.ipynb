# %%
import csv
from datetime import datetime
import re

def map_function_to_profile_logs(function_log_path, profile_log_path):
    # Parsing function log to extract start and end times
    function_map = {}
    with open(function_log_path, 'r') as f_log:
        for line in f_log:
            timestamp_str, action = line.strip().split(" - ")
            timestamp = datetime.strptime(timestamp_str, "%Y-%m-%d %H:%M:%S")
            func_id = re.search(r'\d+', action).group()  # Extracting the function ID

            if action.startswith("<START"):
                if func_id not in function_map:
                    function_map[func_id] = {'start': timestamp, 'end': None}
                else:
                    function_map[func_id]['start'] = timestamp
            elif action.startswith("<END"):
                if func_id in function_map:
                    function_map[func_id]['end'] = timestamp

    # Filtering out functions that do not have an end time
    valid_functions = {k: v for k, v in function_map.items() if v['end'] is not None}

    # Mapping profile logs to valid functions
    function_profile_map = {func_id: [] for func_id in valid_functions}

    with open(profile_log_path, 'r') as p_log:
        reader = csv.DictReader(p_log)
        for row in reader:
            log_time = datetime.strptime(row['time'], "%Y-%m-%d %H:%M:%S")
            for func_id, times in valid_functions.items():
                if times['start'] <= log_time <= times['end']:
                    function_profile_map[func_id].append(row)


    # reverse the mapping from profile time to function
    profiletime_to_function = {}
    for func_id, profile_logs in function_profile_map.items():
        for log in profile_logs:
            profiletime_to_function[str(log['time'])]={"function_id": func_id, "profile_log": log}

    return function_profile_map, profiletime_to_function

# %%
# Example usage:
function_log_path = './function_logs/hello_world.log'
profile_log_path = './profile_logs/hello_world.csv'

function_profile_map, profiletime_to_function = map_function_to_profile_logs(function_log_path, profile_log_path)

# %%
profiletime_to_function
# Out:
# {'2024-08-17 23:15:58': {'function_id': '17049',
#   'profile_log': {'cpu_percent': '7.2',
#    'rss': '9732096',
#    'vms': '34410962944',
#    'pfaults': '3411',
#    'pageins': '0',
#    'time': '2024-08-17 23:15:58',
#    'iteration': '0'}},
#  '2024-08-17 23:15:59': {'function_id': '17049',
#   'profile_log': {'cpu_percent': '91.2',
#    'rss': '9732096',
#    'vms': '34410962944',
#    'pfaults': '3411',
#    'pageins': '0',
#    'time': '2024-08-17 23:15:59',
#    'iteration': '1'}},
#  '2024-08-17 23:16:00': {'function_id': '17049',
#   'profile_log': {'cpu_percent': '90.6',
#    'rss': '9732096',
#    'vms': '34410962944',
#    'pfaults': '3411',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:00',
#    'iteration': '2'}},
#  '2024-08-17 23:16:01': {'function_id': '17049',
#   'profile_log': {'cpu_percent': '99.7',
#    'rss': '9732096',
#    'vms': '34410962944',
#    'pfaults': '3411',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:01',
#    'iteration': '3'}},
#  '2024-08-17 23:16:02': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '99.4',
#    'rss': '9732096',
#    'vms': '34410962944',
#    'pfaults': '3411',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:02',
#    'iteration': '4'}},
#  '2024-08-17 23:16:03': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '72.8',
#    'rss': '9732096',
#    'vms': '34410962944',
#    'pfaults': '3411',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:03',
#    'iteration': '5'}},
#  '2024-08-17 23:16:04': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '27.7',
#    'rss': '33730560',
#    'vms': '34435104768',
#    'pfaults': '9270',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:04',
#    'iteration': '6'}},
#  '2024-08-17 23:16:05': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '20.7',
#    'rss': '51503104',
#    'vms': '34453544960',
#    'pfaults': '13609',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:05',
#    'iteration': '7'}},
#  '2024-08-17 23:16:06': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '48.9',
#    'rss': '91627520',
#    'vms': '34494730240',
#    'pfaults': '23405',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:06',
#    'iteration': '8'}},
#  '2024-08-17 23:16:07': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '16.6',
#    'rss': '98312192',
#    'vms': '34502115328',
#    'pfaults': '25037',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:07',
#    'iteration': '9'}},
#  '2024-08-17 23:16:08': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '52.7',
#    'rss': '131751936',
#    'vms': '34534498304',
#    'pfaults': '33201',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:08',
#    'iteration': '10'}},
#  '2024-08-17 23:16:09': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '45.5',
#    'rss': '141332480',
#    'vms': '34575241216',
#    'pfaults': '42209',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:09',
#    'iteration': '11'}},
#  '2024-08-17 23:16:10': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '4.4',
#    'rss': '144596992',
#    'vms': '34577338368',
#    'pfaults': '43006',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:10',
#    'iteration': '12'}},
#  '2024-08-17 23:16:11': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '50.6',
#    'rss': '154050560',
#    'vms': '34619068416',
#    'pfaults': '52803',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:11',
#    'iteration': '13'}},
#  '2024-08-17 23:16:12': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '44.5',
#    'rss': '177958912',
#    'vms': '34652872704',
#    'pfaults': '61063',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:12',
#    'iteration': '14'}},
#  '2024-08-17 23:16:13': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '8.2',
#    'rss': '184250368',
#    'vms': '34658115584',
#    'pfaults': '62599',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:13',
#    'iteration': '15'}},
#  '2024-08-17 23:16:14': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '48.8',
#    'rss': '208097280',
#    'vms': '34703753216',
#    'pfaults': '72395',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:14',
#    'iteration': '16'}},
#  '2024-08-17 23:16:15': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '42.7',
#    'rss': '242118656',
#    'vms': '34738839552',
#    'pfaults': '80701',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:15',
#    'iteration': '17'}},
#  '2024-08-17 23:16:16': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '7.1',
#    'rss': '248229888',
#    'vms': '34744082432',
#    'pfaults': '82193',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:16',
#    'iteration': '18'}},
#  '2024-08-17 23:16:17': {'function_id': '19555',
#   'profile_log': {'cpu_percent': '48.1',
#    'rss': '288370688',
#    'vms': '34785386496',
#    'pfaults': '91993',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:17',
#    'iteration': '19'}},
#  '2024-08-17 23:16:18': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '44.1',
#    'rss': '323018752',
#    'vms': '34813698048',
#    'pfaults': '100531',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:18',
#    'iteration': '20'}},
#  '2024-08-17 23:16:19': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '34.4',
#    'rss': '88141824',
#    'vms': '34502733824',
#    'pfaults': '125224',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:19',
#    'iteration': '21'}},
#  '2024-08-17 23:16:20': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '60.4',
#    'rss': '88506368',
#    'vms': '34521608192',
#    'pfaults': '125335',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:20',
#    'iteration': '22'}},
#  '2024-08-17 23:16:21': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '9.5',
#    'rss': '88514560',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:21',
#    'iteration': '23'}},
#  '2024-08-17 23:16:22': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '64.0',
#    'rss': '88514560',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:22',
#    'iteration': '24'}},
#  '2024-08-17 23:16:23': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '21.1',
#    'rss': '88514560',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:23',
#    'iteration': '25'}},
#  '2024-08-17 23:16:24': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '34.1',
#    'rss': '88514560',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:24',
#    'iteration': '26'}},
#  '2024-08-17 23:16:25': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '56.4',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:25',
#    'iteration': '27'}},
#  '2024-08-17 23:16:26': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '7.2',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:26',
#    'iteration': '28'}},
#  '2024-08-17 23:16:27': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '46.0',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:27',
#    'iteration': '29'}},
#  '2024-08-17 23:16:28': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '50.8',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:28',
#    'iteration': '30'}},
#  '2024-08-17 23:16:29': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '6.7',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:29',
#    'iteration': '31'}},
#  '2024-08-17 23:16:30': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '55.1',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:30',
#    'iteration': '32'}},
#  '2024-08-17 23:16:31': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '34.7',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:31',
#    'iteration': '33'}},
#  '2024-08-17 23:16:32': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '26.8',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:32',
#    'iteration': '34'}},
#  '2024-08-17 23:16:33': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '53.2',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:33',
#    'iteration': '35'}},
#  '2024-08-17 23:16:34': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '2.3',
#    'rss': '87855104',
#    'vms': '34521608192',
#    'pfaults': '125337',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:34',
#    'iteration': '36'}},
#  '2024-08-17 23:16:35': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '93.1',
#    'rss': '295067648',
#    'vms': '34738012160',
#    'pfaults': '177642',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:35',
#    'iteration': '37'}},
#  '2024-08-17 23:16:36': {'function_id': '41611',
#   'profile_log': {'cpu_percent': '87.7',
#    'rss': '558350336',
#    'vms': '35122708480',
#    'pfaults': '269265',
#    'pageins': '0',
#    'time': '2024-08-17 23:16:36',
#    'iteration': '38'}}}
